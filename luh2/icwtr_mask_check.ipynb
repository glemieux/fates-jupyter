# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
staticfile = "/home/glemieux/Repos/fates/tools/landuse/tests/resources/staticData_quarterdeg.nc"

# %%
ds = xr.open_dataset(staticfile)

# %%
icwtr = ds.icwtr.astype('float64')
icwtr.plot()

# %%
mask = (1-icwtr) / (1-icwtr)
mask.plot()

# %%
(mask.to_dataframe().dropna() == 0.).any()
# Out:
# icwtr    False
# dtype: bool

# %%
(mask.to_dataframe().dropna() != 1.).any()
# Out:
# icwtr    False
# dtype: bool

# %%
(mask.to_dataframe().dropna() == 1.).all().values.item()
# Out:
# True

# %%
import matplotlib.pyplot as plt
import xarray as xr
# import numpy as np
# import xesmf as xe

# %%
luh_names = ['FATES_PATCHAREA_LU', 'FATES_DISTURBANCE_RATE_MATRIX_LULU']

# %%
fn = '/home/glemieux/data-transfer/luh-f45.nc'

# %%
ds = xr.open_dataset(fn)

# %%
landuse_cats = ['primarylands','secondarylands','rangelands','pasturelands','cropland']

# %%
fg = ds.FATES_PATCHAREA_LU.mean(dim="time").plot(x='lon',y='lat',col='fates_levlanduse')

# %%
ds[luh_names[1]].mean(dim='time').plot(x='lon',y='lat',col='fates_levlulu', col_wrap=5)

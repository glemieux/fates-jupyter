# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# %%
fn_ncfbg_base = 'ERS_Ld30.f45_f45_mg37.I2000Clm50FatesCruRsGs.derecho_intel.clm-FatesColdFixedBiogeo/clm2.h0.2000-01-01-00000.nc'
fn_ncfbg = 'ERS_Ld30.f45_f45_mg37.I2000Clm50FatesCruRsGs.derecho_intel.clm-FatesColdNoCompFixedBioGeo.GC.pr1236-ctsm5029_int.clm2.h0.2000-01-01-00000.nc'

fn_sp_base = 'clm2.h0.2000-01-01-00000.nc'
fn_sp = 'SMS.f45_f45_mg37.I2000Clm60FatesSpRsGs.derecho_nvhpc.clm-FatesColdSatPhen.GC.pr1255-fates-final_nvh.clm2.h0.2000-01-01-00000.nc'
# fn_sp_base = 'SMS_Lm1.f45_f45_mg37.I2000Clm60FatesSpCruRsGs.derecho_intel.clm-FatesColdBasic/clm2.h0.2000-01.nc'
# fn_sp = 'SMS_Lm1.f45_f45_mg37.I2000Clm60FatesSpCruRsGs.derecho_intel.clm-FatesColdBasic.GC.pr1236-ctsm5029_int.clm2.h0.2000-01.nc'

fn_full_base = 'SMS_Lm6.f45_f45_mg37.I2000Clm50FatesCruRsGs.derecho_intel.clm-Fates/clm2.h0.2000-01-01-00000.nc'
fn_full = 'SMS_Lm6.f45_f45_mg37.I2000Clm50FatesCruRsGs.derecho_intel.clm-Fates.GC.pr1236-ctsm5029_int.clm2.h0.2000-01-01-00000.nc'

# %%
ds_ncfbg = xr.open_dataset(fn_ncfbg)
ds_sp = xr.open_dataset(fn_sp)
ds_full = xr.open_dataset(fn_full)

ds_ncfbg_base = xr.open_dataset(fn_ncfbg_base)
ds_sp_base = xr.open_dataset(fn_sp_base)
ds_full_base = xr.open_dataset(fn_full_base)

# %%
sp_plants_diff = ds_sp_base.FATES_AREA_PLANTS - ds_sp.FATES_AREA_PLANTS

# %%
sp_plants_diff.isel(time=5).plot()

# %%
sp_ungerm_diff = ds_sp_base.FATES_UNGERM_SEED_BANK - ds_sp.FATES_UNGERM_SEED_BANK

# %%
sp_ungerm_diff.isel(time=5).plot()

# %%
latlonmin = sp_ungerm_diff.argmin(dim=['lat', 'lon'],skipna=True)

# %%
sp_ungerm_diff.lat[latlonmin['lat']]
# Out:
# <xarray.DataArray 'lat' (time: 1)>
# array([-86.])
# Coordinates:
#     lat      (time) float64 -86.0
#   * time     (time) object 2000-02-01 00:00:00
# Attributes:
#     long_name:  coordinate latitude
#     units:      degrees_north

# %%
sp_tveg_diff = ds_sp_base.FATES_TVEG24 - ds_sp.FATES_TVEG24

# %%
sp_tveg_diff.isel(time=5).plot()

# %%
ncfbp_diff_plants = ds_ncfbg_base.FATES_AREA_PLANTS - ds_ncfbg.FATES_AREA_PLANTS

# %%
ncfbp_diff_plants.isel(time=30).plot()

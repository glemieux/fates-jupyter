# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
file_base = "/home/glemieux/data/clm2.h0.2000-01.nc"
file_test = "/home/glemieux/data/SMS_Lm1.f45_f45_mg37.I2000Clm51FatesSpCruRsGs.cheyenne_intel.clm-FatesColdBasic.GC.pr1024-spfix_int.clm2.h0.2000-01.nc"

# %%
ds_base = xr.open_dataset(file_base)
ds_test = xr.open_dataset(file_test)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
ds_base.FATES_LAI.plot(ax=ax1)
ds_test.FATES_LAI.plot(ax=ax2)
(ds_base.FATES_LAI - ds_test.FATES_LAI).plot(ax=ax3)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
ds_base.FATES_TVEG24.plot(ax=ax1)
ds_test.FATES_TVEG24.plot(ax=ax2)
(ds_base.FATES_TVEG24 - ds_test.FATES_TVEG24).plot(ax=ax3)

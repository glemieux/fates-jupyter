# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
file_base = "/home/glemieux/data/SMS_Ld5.f45_f45_mg37.I2000Clm51FatesSpCruRsGs.cheyenne_intel.clm-FatesColdBasic.pr1024-smsLd5-main-diag.clm2.h0.2000-01-01-00000.nc"
file_test = "/home/glemieux/data/SMS_Ld5.f45_f45_mg37.I2000Clm51FatesSpCruRsGs.cheyenne_intel.clm-FatesColdBasic.pr1024-smsLd5-refac-diag.clm2.h0.2000-01-01-00000.nc"

# %%
ds_base = xr.open_dataset(file_base)
ds_test = xr.open_dataset(file_test)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
ds_base.FATES_LAI.isel(time=1).plot(ax=ax1)
ds_test.FATES_LAI.isel(time=1).plot(ax=ax2)
(ds_base.FATES_LAI - ds_test.FATES_LAI).isel(time=1).plot(ax=ax3)

# %%
(ds_base.FATES_LAI - ds_test.FATES_LAI).isel(time=1,lon=slice(27,30),lat=slice(21,24))
# Out:
# <xarray.DataArray 'FATES_LAI' (lat: 3, lon: 3)>
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -1.24344979e-14,  0.00000000e+00],
#        [            nan,             nan,             nan]])
# Coordinates:
#     time     object 2000-01-02 00:00:00
#   * lon      (lon) float64 135.0 140.0 145.0
#   * lat      (lat) float64 -6.0 -2.0 2.0

# %%
cprnc_vals = [29,23]

# %%
# Not sure why this is off by one
(ds_base.FATES_LAI - ds_test.FATES_LAI).isel(time=1,lon=cprnc_vals[0]-1,lat=cprnc_vals[1]-1)
# Out:
# <xarray.DataArray 'FATES_LAI' ()>
# array(-1.24344979e-14)
# Coordinates:
#     time     object 2000-01-02 00:00:00
#     lon      float64 140.0
#     lat      float64 -2.0

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
ds_base.FATES_NPATCHES.isel(time=1).plot(ax=ax1)
ds_test.FATES_NPATCHES.isel(time=1).plot(ax=ax2)
(ds_base.FATES_NPATCHES - ds_test.FATES_NPATCHES).isel(time=1).plot(ax=ax3)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
ds_base.FATES_AREA_PLANTS.isel(time=1).plot(ax=ax1)
ds_test.FATES_AREA_PLANTS.isel(time=1).plot(ax=ax2)
(ds_base.FATES_AREA_PLANTS - ds_test.FATES_AREA_PLANTS).isel(time=1).plot(ax=ax3)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
ds_base.FATES_AREA_TREES.isel(time=1).plot(ax=ax1)
ds_test.FATES_AREA_TREES.isel(time=1).plot(ax=ax2)
(ds_base.FATES_AREA_TREES - ds_test.FATES_AREA_TREES).isel(time=1).plot(ax=ax3)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))
ds_base.FATES_LEAFC.isel(time=1).plot(ax=ax1)
ds_test.FATES_LEAFC.isel(time=1).plot(ax=ax2)
(ds_base.FATES_LEAFC - ds_test.FATES_LEAFC).isel(time=1).plot(ax=ax3)

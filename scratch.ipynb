# %%
import xarray as xr
import cftime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# import panel as pn
# import holoviews as hv
# import hvplot.xarray

# %%
file = '/home/glemieux/scratch/e3sm-cases/mcfates-histtest-lunitptr.fates.lobata.Eb785714bf8-F825579d0/run/mcfates-histtest-lunitptr.fates.lobata.Eb785714bf8-F825579d0.elm.h0.nc'
ds = xr.open_dataset(file)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                             (levgrnd: 15, levlak: 10, levdcmp: 15,
#                                          levsoi: 10, fates_levscls: 13,
#                                          fates_levscag: 91, fates_levscpf: 182,
#                                          fates_levcacls: 2, fates_levcapf: 28,
#                                          fates_levage: 7, fates_levpft: 14,
#                                          fates_levlanduse: 5, fates_levfuel: 6,
#                                          ...
#                                          fates_levelage: 7,
#                                          fates_levagefuel: 42,
#                                          fates_levcdsc: 26, fates_levcdpf: 364,
#                                          fates_levcdam: 2, time: 12,
#                                          hist_interval: 2, lndgrid: 1,
#                                          fates_levlulu: 25, ltype: 9, natpft: 17)
# ...

# %%
tlai = (ds['TLAI'])

# %%
# image = tlai.hvplot('lon', 'lat', cmap='Greens', width=400)
# stream = hv.streams.Tap(source=image, x=0, y=0)
# @pn.depends(stream.param.x, stream.param.y)
# def timeseries(x, y) :
#     return tlai.interactive.sel(lon=x, lat=y, method='nearest').hvplot('time', width=600)

# pn.Column(image, timeseries)

# %%
ds.FATES_AREA_TREES.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ds.FATES_AREA_TREES.plot()
#
# File ~/local/miniconda3/envs/fates-jupyter/lib/python3.12/site-packages/xarray/plot/accessor.py:47, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      45 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      46 def __call__(self, **kwargs) -> Any:
# ---> 47     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/local/miniconda3/envs/fates-jupyter/lib/python3.12/site-packages/xarray/plot/dataarray_plot.py:306, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     302     plotfunc = hist
#     304 kwargs["ax"] = ax
# --> 306 return plotfunc(darray, **kwargs)
#
# ...

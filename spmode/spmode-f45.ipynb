# %% [markdown]
# # SPmode F45 result visualization

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import ctsm_py.fates_xarray_funcs as fx

# %% [markdown]
# ## Load history output data

# %%
fn_base = 'sp_mode-dev053-5year-srof.fates-sci.1.46.2_api.16.1.0-ctsm5.1.dev053-Ca887ad1f-F51112204.intel.clm2.h0.2003-01-01-00000.nc'
data_base = xr.open_dataset(fn_base)

# %% [markdown]
# ## Check the dimension mapping size

# %%
data_base.GPP.dims
# Out:
# ('time', 'lat', 'lon')

# %%
data_base.GPP.time.size
# Out:
# 365

# %% [markdown]
# ## Plot the data

# %% [markdown]
# ### TLAI

# %%
tlai_base = data_base.TLAI

# %%
tstop_idx = 364
f, ax1 = plt.subplots(1, 1, figsize=(10, 6))
tlai_base.isel(time=tstop_idx).plot(ax=ax1)

# %% [markdown]
# ### GPP

# %%
gpp_base = data_base.GPP

# %%
tstop_idx = 364
f, ax1 = plt.subplots(1, 1, figsize=(10, 6))
gpp_base.isel(time=tstop_idx).plot(ax=ax1)

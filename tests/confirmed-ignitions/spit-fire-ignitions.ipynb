# %% [markdown]
# # FATES Spitfire testmod data review

# %% [markdown]
# This notebook visualizes the results of the Spitfire testmods

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import ctsm_py.fates_xarray_funcs as fx
import nc_time_axis

# %% [markdown]
# ## Load history output data

# %%
fn_ci_1 = 'ERS_Ld60.f45_f45_mg37.I2000Clm50FatesCru.cheyenne_intel.clm-FatesFireConfirmedIgnitions.testupdate-FatesFireConfirmedIgnitions.clm2.h0.2000-01.nc'
fn_ci_2 = 'ERS_Ld60.f45_f45_mg37.I2000Clm50FatesCru.cheyenne_intel.clm-FatesFireConfirmedIgnitions.testupdate-FatesFireConfirmedIgnitions.clm2.h0.2000-02.nc'

ci_1_data = xr.open_dataset(fn_ci_1)
ci_2_data = xr.open_dataset(fn_ci_2)

# %% [markdown]
# ## Plot the data

# %% [markdown]
# ### Secondary forest fraction

# %% [markdown]
# Variable diff calculations

# %%
ci_1_ign = ci_1_data.FIRE_IGNITIONS
ci_2_ign = ci_2_data.FIRE_IGNITIONS

# %%
ci_2_ign.time.size
# Out:
# 1

# %%
tstop_idx = 0
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4))
ci_1_ign.isel(time=tstop_idx).plot(ax=ax1)
ci_2_ign.isel(time=tstop_idx).plot(ax=ax2)
# sff_diff.isel(time=tstop_idx).plot(ax=ax3)
